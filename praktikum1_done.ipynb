# %% [markdown]
# <a href="https://colab.research.google.com/github/RaihanDwiPratama/digital_image_processing/blob/main/praktikum1_done.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
print("Hello raihan!")
# Out:
# Hello raihan!

# %%
# fungsi dalam python, pakai tabulasi bukan curly braces
def addNumber(a, b):
  hasil = a + b
  return hasil

# memanggil fungsi
hasil_penambahan = addNumber(1,2)
print(hasil_penambahan)
# Out:
# 3

# %%
planets = ['Mercury', 'Venus', 'Earth']
for planet in planets:
  print(planet, end = ' ') # cetak dalam satu baris, terus dikasih spasi

#looping
print("\n")
for i in range (5):
  print('Doing important work', i)
# Out:
# Mercury Venus Earth
#
# Doing important work 0
# Doing important work 1
# Doing important work 2
# Doing important work 3
# Doing important work 4

# %%
img = cv2.imread('/content/drive/MyDrive/Footage/The-original-cameraman-image.png')
print(img.shape)
# Out:
# (490, 487, 3)

# %%
plt.imshow(img)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=487x490>

# %%
img1 = cv2.imread("/content/drive/MyDrive/Footage/barb.tif")
print(img1.shape)
img2 = cv2.imread("/content/drive/MyDrive/Footage/boat.tif")
print(img2.shape)
# Out:
# (512, 512, 3)
# (512, 512, 3)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].imshow(img1)
axes[1].imshow(img2)

plt.show()

# %%
img = cv2.imread("/content/drive/MyDrive/Footage/monarch.tif")
print(img.shape)

cv2_imshow(img)
# Out:
# (512, 768, 3)
# <PIL.Image.Image image mode=RGB size=768x512>

# %%
img_gray = np.array(0.1140 * img[:, :, 0] + 0.5870 * img[:, :, 1] + 0.2989 *
img[:, :, 2])
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=768x512>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=768x512>
