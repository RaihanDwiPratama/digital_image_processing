# %% [markdown]
# <a href="https://colab.research.google.com/github/RaihanDwiPratama/digital_image_processing/blob/main/praktikum1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
print("Hello raihan!")
# Out:
# Hello raihan!

# %%
# fungsi dalam python, pakai tabulasi bukan curly braces
def addNumber(a, b):
  hasil = a + b
  return hasil

# memanggil fungsi
hasil_penambahan = addNumber(1,2)
print(hasil_penambahan)
# Out:
# 3

# %%
planets = ['Mercury', 'Venus', 'Earth']
for planet in planets:
  print(planet, end = ' ') # cetak dalam satu baris, terus dikasih spasi

#looping
print("\n")
for i in range (5):
  print('Doing important work', i)
# Out:
# Mercury Venus Earth
#
# Doing important work 0
# Doing important work 1
# Doing important work 2
# Doing important work 3
# Doing important work 4

# %%
img = cv2.imread('/content/drive/MyDrive/Footage/The-original-cameraman-image.png')
print(img.shape)
# Out:
# (490, 487, 3)

# %%
plt.imshow(img)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=487x490>
